# %% [markdown]
# ### Imports

# %%
from googleapiclient.discovery import build
import pandas as pd
from google.colab import files, drive
import getpass

# %%
from google.colab import userdata

# %% [markdown]
# ## User Input

# %%
api_key = userdata.get('YOUTUBE_API')

# %%
# Build the YouTube client
youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# ## Get Video IDs for Playlist

# %%
from urllib.parse import urlparse, parse_qs

def get_video_id(url):
    parsed_url = urlparse(url)

    # If URL is a standard YouTube link (e.g., https://www.youtube.com/watch?v=VIDEO_ID)
    if parsed_url.hostname in ["www.youtube.com", "youtube.com"]:
        return parse_qs(parsed_url.query).get("v", [None])[0]

    # If URL is a shortened YouTube link (e.g., https://youtu.be/VIDEO_ID)
    elif parsed_url.hostname in ["youtu.be"]:
        return parsed_url.path.lstrip("/")

    return None

# Example Usage
youtube_url = "https://youtu.be/3YytHYb2qqg?si=9ZHDd_5DmN3f534M"
video_id = get_video_id(youtube_url)
print("Extracted Video ID:", video_id)

# Now you can pass video_ids to the next function
# next_function(video_ids)
# Out:
# Extracted Video ID: 3YytHYb2qqg

# %% [markdown]
# ## Get All Comments

# %%
# Function to get replies for a specific comment
def get_replies(youtube, parent_id):
    replies = []
    next_page_token = None

    while True:
        reply_request = youtube.comments().list(
            part="snippet",
            parentId=parent_id,
            textFormat="plainText",
            maxResults=100,
            pageToken=next_page_token
        )
        reply_response = reply_request.execute()

        for item in reply_response.get('items', []):
            comment = item['snippet']
            replies.append({
                'CommentID': item['id'],  # Unique Comment ID
                'ParentID': parent_id,  # Parent Comment ID
                'Timestamp': comment['publishedAt'],
                'Username': comment['authorDisplayName'],
                'Comment': comment['textDisplay'],
                'Date': comment.get('updatedAt', comment['publishedAt']),
                'Likes': comment['likeCount']
            })

        next_page_token = reply_response.get('nextPageToken')
        if not next_page_token:
            break

    return replies

# Function to get all comments (including replies) for a single video
def get_comments_for_video(youtube, video_id):
    all_comments = []
    next_page_token = None

    while True:
        comment_request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            pageToken=next_page_token,
            textFormat="plainText",
            maxResults=100
        )
        comment_response = comment_request.execute()

        for item in comment_response.get('items', []):
            top_comment = item['snippet']['topLevelComment']['snippet']
            comment_id = item['snippet']['topLevelComment']['id']  # Extract comment ID
            all_comments.append({
                'CommentID': comment_id,
                'ParentID': None,  # Top-level comments have no parent
                'Timestamp': top_comment['publishedAt'],
                'Username': top_comment['authorDisplayName'],
                'Comment': top_comment['textDisplay'],
                'Date': top_comment.get('updatedAt', top_comment['publishedAt']),
                'Likes': top_comment['likeCount']
            })

            # Fetch replies if there are any
            if item['snippet']['totalReplyCount'] > 0:
                all_comments.extend(get_replies(youtube, comment_id))

        next_page_token = comment_response.get('nextPageToken')
        if not next_page_token:
            break

    return all_comments

# List to hold all comments from all videos
all_comments = []

video_comments = get_comments_for_video(youtube, video_id)
all_comments.extend(video_comments)

# Create DataFrame
comments_df = pd.DataFrame(all_comments)

# %%
comments_df.head()
# Out:
#                     CommentID ParentID             Timestamp  \
# 0  Ugz9iIF4cwCpLJd-Jl54AaABAg     None  2024-07-15T16:13:38Z
# 1  UgxnDVp1OB0v5Wf8iD54AaABAg     None  2023-09-18T19:14:31Z
# 2  UgxWtjYys9HNS7ZxRap4AaABAg     None  2023-07-31T16:22:14Z
# 3  Ugwu8Jy2t39SzRnUjoV4AaABAg     None  2023-07-19T23:03:47Z
# 4  Ugyw_I56xAhWu9LctcV4AaABAg     None  2023-07-17T16:54:37Z
#
#                Username                                            Comment  \
# 0       @adityasaha4704                  I thank you for my very existence
# 1       @tippydippy6529  every couple of weeks I find myself watching t...
# 2  @wubbalubbadubdub777              ayahviv ! oued amizour days a rayan !
# 3    @angelagrullon2189  La vibes que transmite esta cancion mierda.......
# 4             @RamonSBK  Vagabond Reminds me everyday that anything is ...
#
#                    Date  Likes
# 0  2024-07-15T16:13:38Z      0
# 1  2023-09-18T19:14:30Z      2
# 2  2023-07-31T16:22:14Z      0
# 3  2023-07-19T23:03:47Z      0
# 4  2023-09-07T12:22:47Z      0

# %%
comments_df.columns
# Out:
# Index(['CommentID', 'ParentID', 'Timestamp', 'Username', 'Comment', 'Date',
#        'Likes'],
#       dtype='object')

# %%
comments_df.sort_values(by = "Date", inplace = True, ascending = False)

# %%
comments_df.shape
# Out:
# (597, 7)

# %%
comments_df.head()
# Out:
#                                              CommentID  \
# 243  UgypwPJSMIyeogONpxl4AaABAg.9U-NgP3TZAA9ZTmUGwGMcT
# 568  Ugzac0O_LaZWK1ZtsCd4AaABAg.9PbmDFOo1LGAA9hGl7xMKp
# 567  Ugzac0O_LaZWK1ZtsCd4AaABAg.9PbmDFOo1LGA9uTGinDLPl
# 566  Ugzac0O_LaZWK1ZtsCd4AaABAg.9PbmDFOo1LGA9QPw1yJ3EQ
# 565  Ugzac0O_LaZWK1ZtsCd4AaABAg.9PbmDFOo1LGA61c1QOZo3B
#
#                        ParentID             Timestamp         Username  \
# 243  UgypwPJSMIyeogONpxl4AaABAg  2022-03-12T12:47:01Z     @buckets3628
# 568  Ugzac0O_LaZWK1ZtsCd4AaABAg  2024-10-29T02:01:04Z  @reidcacaro2919
# 567  Ugzac0O_LaZWK1ZtsCd4AaABAg  2024-10-22T18:42:08Z  @FatGuyEngineer
# 566  Ugzac0O_LaZWK1ZtsCd4AaABAg  2024-10-10T17:16:30Z   @joeyreash9067
# 565  Ugzac0O_LaZWK1ZtsCd4AaABAg  2024-07-18T12:35:46Z        @MR.X-l2u
#
#                                                Comment                  Date  \
# 243  @Aryan ShimrayYou can take any meaning u want ...  2024-11-14T01:09:51Z
# 568  @@massivegat5087agreed, the prelude is a maste...  2024-10-29T02:01:04Z
# 567  ​@@massivegat5087 It's Third Arc (Baltic Sea) ...  2024-10-22T18:42:08Z
# 566  My top 3 stories are 3. Vagabond 2. Berserk an...  2024-10-10T17:16:30Z
# 565  @@Goofy_Benjamin11 Im reading that to really good  2024-07-18T12:35:46Z
#
#      Likes
# 243     23
# 568      1
# 567      0
# 566      0
# 565      0

# %%
comments_df.ParentID.nunique() # number of comments which are threaded ie replies exist
# Out:
# 48

# %%
comments_df.shape
# Out:
# (597, 7)

# %% [markdown]
# ### STRUCTURE THE DATA ACCORDING TO HIERARCHIES
# ### MAKE NEW DATAFRAME FOR THAT

# %%
hdf = pd.DataFrame([], columns = ['CommentID', 'Timestamp', 'Username', 'Comment', 'Date', 'Likes', 'reply_comment_id', 'replies'])

for i, x in enumerate(comments_df.ParentID):
  # if parent id is None add it into a dataframe
  if x == None:
    hdf.loc[len(hdf)] = [ comments_df.iloc[i, 0],  # comment id
                          comments_df.iloc[i, 2],  # timestamp
                          comments_df.iloc[i, 3],  # user
                          comments_df.iloc[i, 4],  # comment text
                          comments_df.iloc[i, 5],  # date
                          comments_df.iloc[i, 6],  # likes
                          "",                      # reply comment id
                          ""                       # replies
                        ]

# %%
hdf.sort_values(by = "Likes", ascending = False)
# Out:
#                       CommentID             Timestamp  \
# 190  Ugzac0O_LaZWK1ZtsCd4AaABAg  2021-07-10T11:23:55Z
# 180  UgzyQhJPJ-zHhKkDN0B4AaABAg  2021-08-30T17:34:52Z
# 192  Ugx_LdgI0vWOumWYS_d4AaABAg  2021-07-10T05:49:27Z
# 161  UgypwPJSMIyeogONpxl4AaABAg  2021-10-27T10:47:26Z
# 186  UgxMNe48oT4QElg2klN4AaABAg  2021-07-21T01:06:14Z
# ..                          ...                   ...
# 55   Ugydq8sQ0J5stCWajt94AaABAg  2021-12-19T13:57:22Z
# 111  Ugydsz9JN6mW9hz9g8R4AaABAg  2021-11-12T16:35:09Z
# 110  UgzGTHZUQL4XS12M7Zl4AaABAg  2021-11-12T18:39:27Z
# 56   Ugz5i0vxPJAIu-Em5Vh4AaABAg  2021-12-18T12:46:19Z
# 0    Ugz9iIF4cwCpLJd-Jl54AaABAg  2024-07-15T16:13:38Z
#
#                             Username  \
# 190                        @MR.X-l2u
# 180                   @cheeseman2219
# 192              @abandonaccount8582
# 161                       @DavionX13
# 186  @sovereignrepublicofcopticx6397
# ..                               ...
# 55                     @Ryan.jorgeBR
# 111               @masterofdeath5498
# 110                         @TeeRkee
# 56                   @jaid2salvia961
# 0                    @adityasaha4704
#
#                                                Comment                  Date  \
# 190  Vegabond and Berserk are the two best manga ev...  2021-07-10T11:23:55Z
# 180  Musashi vs 70 Yoshioka men was the most memora...  2021-08-30T17:34:52Z
# 192  Vegabond is underrated more people should read...  2021-07-10T05:49:27Z
# 161  Preoccupied with a single leaf, you won't see ...  2021-10-27T10:47:26Z
# 186                 The best part is that he was real.  2021-07-21T01:06:14Z
# ..                                                 ...                   ...
# 55                                              Nice 👏  2021-12-19T13:57:22Z
# 111                    Очень жаль что не закончили её.  2021-11-12T16:35:09Z
# 110                                        Anime when?  2021-11-12T18:39:35Z
# 56    This amv insipired me to watch vagabond . Ty bro  2021-12-18T12:46:19Z
# 0                    I thank you for my very existence  2024-07-15T16:13:38Z
#
#      Likes reply_comment_id replies
# 190   2892
# 180   1176
# 192   1158
# 161    928
# 186    913
# ..     ...              ...     ...
# 55       0
# 111      0
# 110      0
# 56       0
# 0        0
#
# [196 rows x 8 columns]

# %% [markdown]
# ## ADD REPLIES TO PARENT COMMENTS, NO NEED FOR SAVING HIERARCHIES, WE JUST NEED THE TEXT.

# %%
#hdf = pd.DataFrame([], columns = ['CommentID', 'Timestamp', 'Username', 'Comment', 'Date', 'Likes', 'reply_comment_id', 'replies'])
pids = list(hdf.CommentID)
iop = 0

for i, x in enumerate(comments_df.ParentID):
  if x:
    subids = [x.split(" || ") for x in hdf.reply_comment_id]
    #print(subids)
    if x in pids:
      iop +=1
      # hdfs index, get index of parent comment id from its df
      id = hdf[hdf.CommentID == x].index
      # on that index add our information
      hdf.loc[id, "reply_comment_id"] +=  " || " + comments_df.loc[i, "CommentID"]
      hdf.loc[id, "replies"] += " || " + comments_df.loc[i, "Comment"]
      #print(hdf.loc[id, "reply_comment_id"])

    else:
      print("here")
      for k, subcs in enumerate(subids):
        if x in subcs:
          hdf.loc[k, "reply_comment_id"] +=  " || " + comments_df.loc[i, "CommentID"]
          hdf.loc[k, "replies"] += " || " + comments_df.loc[i, "Comment"]

# %%
hdf.shape
# Out:
# (196, 8)

# %%
f"there are {len(hdf)} independent comments"
# Out:
# 'there are 196 independent comments'

# %% [markdown]
# ### Output to CSV

# %%
# Export whole dataset to the local machine as CSV File
csv_file = 'comments_data.csv'  # Name your file
hdf.to_csv(csv_file, index=False)

from google.colab import files

# Trigger a download to your local machine
files.download(csv_file)
